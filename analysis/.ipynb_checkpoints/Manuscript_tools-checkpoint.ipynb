# %%
# %matplotlib inline

# %%
palette=['#C78E52','#3F5C76','#656855']
labels=['Desensitized','Open','Closed']

# %%
palette_per = [(0.40, 0.41, 0.33),
               (0.25, 0.36, 0.46),
               (0.78, 0.56, 0.32)]

# %%
from matplotlib.colors import ListedColormap, LinearSegmentedColormap
colors = [palette_per[0], (1, 1, 1), (1,0,0)]
cmap_name = 'de'
cmap = LinearSegmentedColormap.from_list(cmap_name, colors, N=100)

# %%
import matplotlib

# %%
import ipympl

# %%
import ptitprince as pt
import seaborn as sns
sns.set(style="ticks",context='paper',font_scale=2)
import matplotlib.collections as clt
sns.despine()
from matplotlib.ticker import MultipleLocator

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl

colors = [palette_per[0], (1, 1, 1), (1,0,0)]
cmap_name = 'closed'
cmap = LinearSegmentedColormap.from_list(cmap_name, colors, N=100)

fig, ax = plt.subplots(figsize=(1,10))
fig.subplots_adjust(bottom=0.5)

norm = mpl.colors.Normalize(vmin=0, vmax=6)

cb1 = mpl.colorbar.ColorbarBase(ax, cmap=cmap,
                                norm=norm,
                                orientation='vertical')
cb1.set_label('Residence Time (μs)')
plt.savefig('Figures/CG/residence_time_closed_cbar.pdf',bbox_inches = 'tight', pad_inches=0.1, transparent=False)

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl

colors = [palette_per[1], (1, 1, 1), (1,0,0)]
cmap_name = 'open'
cmap = LinearSegmentedColormap.from_list(cmap_name, colors, N=100)

fig, ax = plt.subplots(figsize=(1,10))
fig.subplots_adjust(bottom=0.5)

norm = mpl.colors.Normalize(vmin=0, vmax=6)

cb1 = mpl.colorbar.ColorbarBase(ax, cmap=cmap,
                                norm=norm,
                                orientation='vertical')
cb1.set_label('Residence Time (μs)')
plt.savefig('Figures/CG/residence_time_open_cbar.pdf',bbox_inches = 'tight', pad_inches=0.1, transparent=False)

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl

colors = [palette_per[2], (1, 1, 1), (1,0,0)]
cmap_name = 'de'
cmap = LinearSegmentedColormap.from_list(cmap_name, colors, N=100)

fig, ax = plt.subplots(figsize=(1,10))
fig.subplots_adjust(bottom=0.5)

norm = mpl.colors.Normalize(vmin=0, vmax=6)

cb1 = mpl.colorbar.ColorbarBase(ax, cmap=cmap,
                                norm=norm,
                                orientation='vertical')
cb1.set_label('Residence Time (μs)')
plt.savefig('Figures/CG/residence_time_de_cbar.pdf',bbox_inches = 'tight', pad_inches=0.1, transparent=False)

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl

colors = [palette_per[0], (1, 1, 1), (1,0,0)]
cmap_name = 'closed'
cmap = LinearSegmentedColormap.from_list(cmap_name, colors, N=100)

fig, ax = plt.subplots(figsize=(1,10))
fig.subplots_adjust(bottom=0.5)

norm = mpl.colors.Normalize(vmin=0, vmax=100)

cb1 = mpl.colorbar.ColorbarBase(ax, cmap=cmap,
                                norm=norm,
                                orientation='vertical')
cb1.set_label('Occupancy (%)')
plt.savefig('Figures/CG/occupancy_closed_cbar.pdf',bbox_inches = 'tight', pad_inches=0.1, transparent=False)

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl

colors = [palette_per[1], (1, 1, 1), (1,0,0)]
cmap_name = 'open'
cmap = LinearSegmentedColormap.from_list(cmap_name, colors, N=100)

fig, ax = plt.subplots(figsize=(1,10))
fig.subplots_adjust(bottom=0.5)

norm = mpl.colors.Normalize(vmin=0, vmax=100)

cb1 = mpl.colorbar.ColorbarBase(ax, cmap=cmap,
                                norm=norm,
                                orientation='vertical')
cb1.set_label('Occupancy (%)')
plt.savefig('Figures/CG/occupancy_open_cbar.pdf',bbox_inches = 'tight', pad_inches=0.1, transparent=False)

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl

colors = [palette_per[2], (1, 1, 1), (1,0,0)]
cmap_name = 'de'
cmap = LinearSegmentedColormap.from_list(cmap_name, colors, N=100)

fig, ax = plt.subplots(figsize=(1,10))
fig.subplots_adjust(bottom=0.5)

norm = mpl.colors.Normalize(vmin=0, vmax=100)

cb1 = mpl.colorbar.ColorbarBase(ax, cmap=cmap,
                                norm=norm,
                                orientation='vertical')
cb1.set_label('Occupancy (%)')
plt.savefig('Figures/CG/occupancy_de_cbar.pdf',bbox_inches = 'tight', pad_inches=0.1, transparent=False)

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl

fig, ax = plt.subplots(figsize=(1,10))
fig.subplots_adjust(bottom=0.5)

norm = mpl.colors.Normalize(vmin=0, vmax=6)

cb1 = mpl.colorbar.ColorbarBase(ax, cmap=cmap,
                                norm=norm,
                                orientation='vertical')
cb1.set_label('Residence Time (μs)')
#plt.savefig('Figures/CG/residence_time_de_cbar.png',bbox_inches = 'tight', pad_inches=0.1, transparent=False)
# Out:
# <div id='4ec0cc05-34c3-45a4-b478-b7a5ae733f10'></div>

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl

colors = [palette_per[2], (1, 1, 1), (1,0,0)]
cmap_name = 'de'
cmap = LinearSegmentedColormap.from_list(cmap_name, colors, N=100)


fig, ax = plt.subplots(figsize=(1,10))
fig.subplots_adjust(bottom=0.5)

norm = mpl.colors.Normalize(vmin=0, vmax=0.06)

cb1 = mpl.colorbar.ColorbarBase(ax, cmap=cmap,
                                norm=norm,
                                orientation='vertical')
cb1.set_label('Density')
plt.savefig('Figures/CG/density_bar_de.pdf',bbox_inches = 'tight', pad_inches=0.1, transparent=False)
